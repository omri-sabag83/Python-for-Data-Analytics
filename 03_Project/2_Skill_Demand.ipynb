# %% [markdown]
# # What are the most demanded skills for the most popular data roles?
#
# #### Methodology
# 1. Clean-up skill column
# 2. Calculate skill count based on `job_title_short`
# 3. Calculate skill percentage
# 4. Plot final findings
#
# #### Original Exploration
# [13_Matplotlib_Format_Charts.ipynb](../02_Advanced/13_Matplotlib_Format_Charts.ipynb)

# %% [markdown]
# ## Import Libraries and Data

# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from load_data import load_data

# Load the cleaned data_jobs dataset.
# First run downloads it from Hugging Face and caches it to data/data_jobs.parquet;
# every later run reads that cache instead. See load_data.py for the details.
df = load_data()

# %% [markdown]
# ## Filter Data for a selected country
#
# Filter the data for the market of the selected country.

# %%
from config import SELECTED_COUNTRY

# filename-safe form of the country, used when saving chart images (e.g. "united_kingdom")
country_slug = SELECTED_COUNTRY.lower().replace(" ", "_")

df_country = df[df['job_country'] == SELECTED_COUNTRY]

# %% [markdown]
# ## Explode Skills

# %% [markdown]
# Converts the `job_skills` column from string representations of lists into actual list objects and then expands these lists so each skill appears in its own row. It then displays the `job_title_short` and `job_skills` columns, allowing us to analyze the distribution of skills across different data job titles.

# %%
df_skills = df_country.explode('job_skills')

df_skills[['job_title_short', 'job_skills']]
# Out:
#               job_title_short  job_skills
# 15              Data Engineer      python
# 15              Data Engineer         sql
# 15              Data Engineer    power bi
# 45        Senior Data Analyst         sql
# 45        Senior Data Analyst      python
# ...                       ...         ...
# 785642          Data Engineer        qlik
# 785642          Data Engineer  confluence
# 785642          Data Engineer        jira
# 785676  Senior Data Scientist           r
# 785676  Senior Data Scientist      python
#
# [167546 rows x 2 columns]

# %% [markdown]
# ## Count Skills per Job Title
#
# Groups DataFrame by `job_skills` and `job_title_short`, counting the occurrences of each skill within each job title. Then resets the index of the Series to turn it back into a DataFrame and renames the series holding the count to 'count'. The final DataFrame, `df_skills_count`, shows the frequency of each skill with each job title.

# %%
# Group by job_skills and job_title_short and count the number of occurrences
df_skills_count = df_skills.groupby(['job_skills', 'job_title_short']).size()

# Name the count column as count
df_skills_count = df_skills_count.reset_index(name='skill_count')

# Sort the values by skill_count in descending order
df_skills_count.sort_values(by='skill_count', ascending=False, inplace=True)

df_skills_count
# Out:
#       job_skills            job_title_short  skill_count
# 1163         sql              Data Engineer         7050
# 915       python              Data Engineer         6462
# 916       python             Data Scientist         6329
# 88         azure              Data Engineer         4865
# 1162         sql               Data Analyst         4467
# ...          ...                        ...          ...
# 1368      vue.js          Software Engineer            1
# 1367      vue.js       Senior Data Engineer            1
# 514   javascript  Machine Learning Engineer            1
# 551        julia          Software Engineer            1
# 1418        zoom          Software Engineer            1
#
# [1419 rows x 3 columns]

# %% [markdown]
# ## Create List of Top Roles
#
# #### Focus: the most common job titles in the selected market
#
# Filter the job titles by which ones are the most popular.

# %%
df_job_title_count = df_country.groupby('job_title_short').size().sort_values(ascending=False).reset_index(name='jobs_total')
df_job_title_count
# Out:
#              job_title_short  jobs_total
# 0              Data Engineer       11807
# 1               Data Analyst       10482
# 2             Data Scientist        9148
# 3       Senior Data Engineer        3337
# 4      Senior Data Scientist        2367
# 5        Senior Data Analyst        1356
# 6           Business Analyst         827
# 7          Software Engineer         541
# 8  Machine Learning Engineer         317
# 9             Cloud Engineer         193

# %%
top_n_roles = 4
job_titles = df_job_title_count['job_title_short'].head(top_n_roles).tolist()

f'Top {top_n_roles} Job Titles in {SELECTED_COUNTRY} are: ' + ', '.join(job_titles)
# Out:
# 'Top 4 Job Titles in United Kingdom are: Data Engineer, Data Analyst, Data Scientist, Senior Data Engineer'

# %% [markdown]
# ## Plot Skill Counts

# %% [markdown]
# Creates a horizontal bar chart of the top 5 skills for each of the top roles, showing how often each skill appears.

# %%
top_n_skills = 5

fig, ax = plt.subplots(len(job_titles), 1)

sns.set_theme(style='ticks')

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_n_skills)[::-1]
    sns.barplot(data=df_plot, x='skill_count', y='job_skills', ax=ax[i], hue='skill_count', palette='dark:b_r')
    ax[i].set_title(job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].get_legend().remove()
    # ax[i].set_xlim(0, 45000) # make the scales the same, but constant

# use the largest x-limit from all axes
max_x = max(a.get_xlim()[1] for a in ax)

for a in ax:
    a.set_xlim(0, max_x) # make the scales the same, but dynamic

fig.suptitle('Top ' + str(top_n_skills) + ' Skills Requested in ' + SELECTED_COUNTRY + ' Job Postings', fontsize=15)
fig.tight_layout(h_pad=0.5) # fix the overlap
plt.show()

# %% [markdown]
# ## Convert Counts to Percentages
#
# #### Focus: Counts don't show what portions of jobs are requesting these skills
#
# So we'll convert the counts into percentages which helps us understand how each job title represents relative to the entire dataset.

# %% [markdown]
# Before we can calculate the percentages we need the total counts for the jobs posted by job title. Calculate the frequency of each job title using the `value_counts()` method on the `job_title_short` column. Then reset the index to transform the Series into a DataFrame and renames the columns to `job_title_short` and `total`. The DataFrame `df_job_title_count` now holds a list of job titles alongside their total occurrences.

# %%
df_job_title_count
# Out:
#              job_title_short  jobs_total
# 0              Data Engineer       11807
# 1               Data Analyst       10482
# 2             Data Scientist        9148
# 3       Senior Data Engineer        3337
# 4      Senior Data Scientist        2367
# 5        Senior Data Analyst        1356
# 6           Business Analyst         827
# 7          Software Engineer         541
# 8  Machine Learning Engineer         317
# 9             Cloud Engineer         193

# %% [markdown]
# Then we calculate the percentages. First merge `df_skills_count` and `df_job_title_count`, based on the 'job_title_short' column, ensuring each skill count is associated with the total number of job postings for that title. Then calculate the percentage of each skill within its job title by dividing the skill count by the total job postings and multiplying by 100, adding this new data as a 'percentage' column.

# %%
df_skills_perc = pd.merge(df_skills_count, df_job_title_count, on='job_title_short', how='left')

df_skills_perc['skill_percent'] = (df_skills_perc['skill_count'] / df_skills_perc['jobs_total']) * 100

df_skills_perc
# Out:
#       job_skills            job_title_short  skill_count  jobs_total  \
# 0            sql              Data Engineer         7050       11807
# 1         python              Data Engineer         6462       11807
# 2         python             Data Scientist         6329        9148
# 3          azure              Data Engineer         4865       11807
# 4            sql               Data Analyst         4467       10482
# ...          ...                        ...          ...         ...
# 1414      vue.js          Software Engineer            1         541
# 1415      vue.js       Senior Data Engineer            1        3337
# 1416  javascript  Machine Learning Engineer            1         317
# 1417       julia          Software Engineer            1         541
# 1418        zoom          Software Engineer            1         541
#
#       skill_percent
# 0         59.710341
# 1         54.730245
# 2         69.184521
# 3         41.204370
# 4         42.615913
# ...

# %% [markdown]
# ## Plot Percentage Count

# %% [markdown]
# Filters and sorts a DataFrame to get the top 5 skill percentages for these top roles. After sorting the skills by descending percentage, reverse the order of these top 5 entries to use in a horizontal bar plot, which by default starts plotting from the bottom.

# %%
fig, ax = plt.subplots(len(job_titles), 1)

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_perc[df_skills_perc['job_title_short'] == job_title].head(top_n_skills) # add [::-1] to invert bars order
    sns.barplot(data=df_plot, x='skill_percent', y='job_skills', ax=ax[i], hue='skill_count', palette='dark:b_r')
    ax[i].set_title(job_title)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].get_legend().remove()
    # ax[i].set_xlim(0, 78) # make the scales the same, but constant

    # use the largest x-limit from all axes
    max_x = max(a.get_xlim()[1] for a in ax)
    ax[i].set_xlim(0, max_x) # make the scales the same, but dynamic
    
    # remove the x-axis tick labels for better readability
    if i != len(job_titles) - 1:
        ax[i].set_xticks([])

    # label the percentage on the bars
    for n, v in enumerate(df_plot['skill_percent']):
        ax[i].text(v + 1, n, f'{v:.0f}%', va='center')

fig.suptitle('Likelihood of Top ' + str(top_n_skills) + ' Skills Requested in ' + SELECTED_COUNTRY + ' Job Postings', fontsize=15)
fig.tight_layout(h_pad=.8)
plt.savefig(f'images/skill_likelihood_{country_slug}.png', bbox_inches='tight', dpi=150)
plt.show()
